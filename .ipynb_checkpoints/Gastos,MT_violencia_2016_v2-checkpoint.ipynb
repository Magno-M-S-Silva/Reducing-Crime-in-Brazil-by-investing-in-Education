# %% [markdown]
# # Expenditure effects and expenditure necessity for lowering crime rates.

# %% [markdown]
# ### The objective of this notebook is answering how much expenditure in either security or education state governments in Brazil would need to achieve the same violence rates that the state of São Paulo has.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm
# %matplotlib notebook

# %% [markdown]
# ### Our dataset consists of yearly data from each brazilian state ranging from 2013 to 2016 about:
# #### 1) real security expenditure ("Seguranca Publica Real")
# #### 2) real education expenditure ("Educacao Real")
# #### 3) real average wages ("Salário médio real")
# #### 4) unemployment rate ("Desemprego")
# #### 5) violent death rates ("Tx de mortes violentas")
# #### 6) population size ("População").
#
# #### It's a rather small data set lacking most of all a instrumental variable to evaluate the correct causility effect of expenditures on violent death rates. This is why it must be very clear that this experiment is just a quick and simple overview of the problem.

# %%
dados=pd.read_csv('E:\\Outros arquivos e pastas\\blogs\\gastos e violencia\\base.csv',sep=";",encoding='latin1')

# %%
dados.head()
# Out:
#     Estado Sigla   Ano  Seguranca Publica Real  Educacao Real  \
# 0     Acre    AC  2013             371661177.6    857385697.7
# 1     Acre    AC  2014             412349943.8    856196174.8
# 2     Acre    AC  2015             354750384.1    788389932.2
# 3     Acre    AC  2016             345980702.1    781317690.5
# 4  Alagoas    AL  2013             948730236.2    946147596.4
#
#    Salário médio real  Desemprego  Tx de mortes violentas  População
# 0         1646.000000         8.4                   27.69     776463
# 1         1581.653695         7.9                   25.82     790101
# 2         1489.406472         8.8                   29.12     803513
# 3         1285.450128        10.3                   29.75     816687
# 4         1250.000000        10.2                   68.86    3300935

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 9 columns):
# Estado                    108 non-null object
# Sigla                     108 non-null object
# Ano                       108 non-null int64
# Seguranca Publica Real    108 non-null float64
# Educacao Real             108 non-null float64
# Salário médio real        108 non-null float64
# Desemprego                108 non-null float64
# Tx de mortes violentas    108 non-null float64
# População                 108 non-null int64
# dtypes: float64(5), int64(2), object(2)
# memory usage: 7.7+ KB

# %% [markdown]
# ###### Creating logarithm versions of some of the mais variables

# %%
dados['Ln_SP']=np.log(dados['Seguranca Publica Real'])
dados['Ln_Educ']=np.log(dados['Educacao Real'])
dados['Ln_Sal']=np.log(dados['Salário médio real'])
dados['Ln_População']=np.log(dados['População'])

# %%
dados['cnst']=1

# %%
dados.head()
# Out:
#     Estado Sigla   Ano  Seguranca Publica Real  Educacao Real  \
# 0     Acre    AC  2013             371661177.6    857385697.7
# 1     Acre    AC  2014             412349943.8    856196174.8
# 2     Acre    AC  2015             354750384.1    788389932.2
# 3     Acre    AC  2016             345980702.1    781317690.5
# 4  Alagoas    AL  2013             948730236.2    946147596.4
#
#    Salário médio real  Desemprego  Tx de mortes violentas  População  \
# 0         1646.000000         8.4                   27.69     776463
# 1         1581.653695         7.9                   25.82     790101
# 2         1489.406472         8.8                   29.12     803513
# 3         1285.450128        10.3                   29.75     816687
# 4         1250.000000        10.2                   68.86    3300935
#
#        Ln_SP    Ln_Educ    Ln_Sal  Ln_População  cnst
# 0  19.733493  20.569398  7.406103     13.562504     1
# 1  19.837383  20.568010  7.366226     13.579916     1
# 2  19.686925  20.485503  7.306133     13.596749     1
# 3  19.661894  20.476492  7.158864     13.613011     1
# 4  20.670635  20.667909  7.130899     15.009716     1

# %%
cols=list(dados.columns)
for i in range(len(cols)):
    print(str(i)+' '+cols[i])
# Out:
# 0 Estado
# 1 Sigla
# 2 Ano
# 3 Seguranca Publica Real
# 4 Educacao Real
# 5 Salário médio real
# 6 Desemprego
# 7 Tx de mortes violentas
# 8 População
# 9 Ln_SP
# 10 Ln_Educ
# 11 Ln_Sal
# 12 Ln_População
# 13 cnst

# %% [markdown]
# ###### Choosing the first set of independent variables

# %%
cols_reg_1=[cols[6]]+cols[9:]
cols_reg_1
# Out:
# ['Desemprego', 'Ln_SP', 'Ln_Educ', 'Ln_Sal', 'Ln_População', 'cnst']

# %%
result=sm.OLS(dados['Tx de mortes violentas'],dados[cols_reg_1]).fit()
print(result.summary())
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Tx de mortes violentas   R-squared:                       0.387
# Model:                                OLS   Adj. R-squared:                  0.357
# Method:                     Least Squares   F-statistic:                     12.89
# Date:                    Fri, 23 Feb 2018   Prob (F-statistic):           1.02e-09
# Time:                            14:24:45   Log-Likelihood:                -400.60
# No. Observations:                     108   AIC:                             813.2
# Df Residuals:                         102   BIC:                             829.3
# Df Model:                               5
# Covariance Type:                nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Desemprego       1.6233      0.399      4.064      0.000         0.831     2.416
# Ln_SP            3.0986      1.827      1.696      0.093        -0.525     6.722
# Ln_Educ        -13.3939      3.758     -3.564      0.001       -20.849    -5.939
# Ln_Sal          -1.4515      5.474     -0.265      0.791       -12.309     9.406
# Ln_População     6.8991      3.353      2.058      0.042         0.249    13.549
# cnst           146.3615     31.755      4.609      0.000        83.376   209.347
# ==============================================================================
# Omnibus:                        2.992   Durbin-Watson:                   0.958
# Prob(Omnibus):                  0.224   Jarque-Bera (JB):                2.557
# Skew:                           0.269   Prob(JB):                        0.279
# Kurtosis:                       2.473   Cond. No.                     1.15e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.15e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# #### This is the first of many regressions that clearly find a positive effect of security effect on crime. This result is probably influenced by the reverse causality effect of rising crime pressuring governors to raise expenditure in security even though it's results may be quite questionable.
#
# #### All the other results seem to go in the expected directions. Education expenditure reduces violent death rates, raising salaries and reducing unemployment too.

# %% [markdown]
# #

# %% [markdown]
# ##### Maybe security expenditure this year has an effect on next year's crime rates? Let's test that.

# %%
dados['Lag_Ln_SP']=np.nan
for i in range(1,len(dados)):
    if dados.loc[i,'Estado']==dados.loc[i-1,'Estado']:
        dados.loc[i,'Lag_Ln_SP']=dados.loc[i-1,'Ln_SP']

# %%
dados.head()
# Out:
#     Estado Sigla   Ano  Seguranca Publica Real  Educacao Real  \
# 0     Acre    AC  2013             371661177.6    857385697.7
# 1     Acre    AC  2014             412349943.8    856196174.8
# 2     Acre    AC  2015             354750384.1    788389932.2
# 3     Acre    AC  2016             345980702.1    781317690.5
# 4  Alagoas    AL  2013             948730236.2    946147596.4
#
#    Salário médio real  Desemprego  Tx de mortes violentas  População  \
# 0         1646.000000         8.4                   27.69     776463
# 1         1581.653695         7.9                   25.82     790101
# 2         1489.406472         8.8                   29.12     803513
# 3         1285.450128        10.3                   29.75     816687
# 4         1250.000000        10.2                   68.86    3300935
#
#        Ln_SP    Ln_Educ    Ln_Sal  Ln_População  cnst  Lag_Ln_SP
# 0  19.733493  20.569398  7.406103     13.562504     1        NaN
# 1  19.837383  20.568010  7.366226     13.579916     1  19.733493
# 2  19.686925  20.485503  7.306133     13.596749     1  19.837383
# 3  19.661894  20.476492  7.158864     13.613011     1  19.686925
# 4  20.670635  20.667909  7.130899     15.009716     1        NaN

# %%
dados_non_nan=dados.copy()
dados_non_nan=dados_non_nan.dropna(axis=0,how='any')
dados_non_nan.head()
# Out:
#     Estado Sigla   Ano  Seguranca Publica Real  Educacao Real  \
# 1     Acre    AC  2014             412349943.8   8.561962e+08
# 2     Acre    AC  2015             354750384.1   7.883899e+08
# 3     Acre    AC  2016             345980702.1   7.813177e+08
# 5  Alagoas    AL  2014             985595915.5   1.002443e+09
# 6  Alagoas    AL  2015             876353075.7   8.458958e+08
#
#    Salário médio real  Desemprego  Tx de mortes violentas  População  \
# 1         1581.653695         7.9                   25.82     790101
# 2         1489.406472         8.8                   29.12     803513
# 3         1285.450128        10.3                   29.75     816687
# 5         1291.260949         9.5                   66.27    3321730
# 6         1113.233686        11.1                   54.12    3340932
#
#        Ln_SP    Ln_Educ    Ln_Sal  Ln_População  cnst  Lag_Ln_SP
# 1  19.837383  20.568010  7.366226     13.579916     1  19.733493
# 2  19.686925  20.485503  7.306133     13.596749     1  19.837383
# 3  19.661894  20.476492  7.158864     13.613011     1  19.686925
# 5  20.708757  20.725706  7.163374     15.015996     1  20.670635
# 6  20.591280  20.555907  7.015024     15.021760     1  20.708757

# %%
cols=list(dados.columns)
for i in range(len(cols)):
    print(str(i)+' '+cols[i])
# Out:
# 0 Estado
# 1 Sigla
# 2 Ano
# 3 Seguranca Publica Real
# 4 Educacao Real
# 5 Salário médio real
# 6 Desemprego
# 7 Tx de mortes violentas
# 8 População
# 9 Ln_SP
# 10 Ln_Educ
# 11 Ln_Sal
# 12 Ln_População
# 13 cnst
# 14 Lag_Ln_SP

# %% [markdown]
# ##### Second regression's independent variables

# %%
cols_reg_2=[cols[6]]+cols[10:]
cols_reg_2
# Out:
# ['Desemprego', 'Ln_Educ', 'Ln_Sal', 'Ln_População', 'cnst', 'Lag_Ln_SP']

# %%
result=sm.OLS(dados_non_nan['Tx de mortes violentas'],dados_non_nan[cols_reg_2]).fit()
print(result.summary())
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Tx de mortes violentas   R-squared:                       0.397
# Model:                                OLS   Adj. R-squared:                  0.357
# Method:                     Least Squares   F-statistic:                     9.882
# Date:                    Fri, 23 Feb 2018   Prob (F-statistic):           2.76e-07
# Time:                            14:24:45   Log-Likelihood:                -299.32
# No. Observations:                      81   AIC:                             610.6
# Df Residuals:                          75   BIC:                             625.0
# Df Model:                               5
# Covariance Type:                nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Desemprego       1.5167      0.444      3.415      0.001         0.632     2.402
# Ln_Educ        -12.7236      4.160     -3.059      0.003       -21.011    -4.436
# Ln_Sal          -2.5111      6.383     -0.393      0.695       -15.227    10.205
# Ln_População     6.3235      3.797      1.665      0.100        -1.241    13.888
# cnst           149.9367     35.284      4.249      0.000        79.648   220.225
# Lag_Ln_SP        3.0704      1.934      1.587      0.117        -0.783     6.924
# ==============================================================================
# Omnibus:                        2.391   Durbin-Watson:                   1.287
# Prob(Omnibus):                  0.303   Jarque-Bera (JB):                1.943
# Skew:                           0.237   Prob(JB):                        0.379
# Kurtosis:                       2.408   Cond. No.                     1.11e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.11e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ##### Still nothing...

# %% [markdown]
# #
#
#
# ##### Let's make some rough graphs just because

# %%
plt.figure()
plt.scatter(dados['Ln_SP'],dados['Tx de mortes violentas'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.1666666666666">

# %%
plt.figure()
plt.scatter(dados['Desemprego'],dados['Tx de mortes violentas'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.1666666666666">

# %%
plt.figure()
plt.scatter(dados['Ln_Sal'],dados['Tx de mortes violentas'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.1666666666666">

# %% [markdown]
# ##### Let's instead look at government expenditure per person and see what we get

# %%
dados['SP por Pop']=dados['Seguranca Publica Real']/dados['População']

# %%
dados['Educ por Pop']=dados['Educacao Real']/dados['População']

# %%
dados.head()
# Out:
#     Estado Sigla   Ano  Seguranca Publica Real  Educacao Real  \
# 0     Acre    AC  2013             371661177.6    857385697.7
# 1     Acre    AC  2014             412349943.8    856196174.8
# 2     Acre    AC  2015             354750384.1    788389932.2
# 3     Acre    AC  2016             345980702.1    781317690.5
# 4  Alagoas    AL  2013             948730236.2    946147596.4
#
#    Salário médio real  Desemprego  Tx de mortes violentas  População  \
# 0         1646.000000         8.4                   27.69     776463
# 1         1581.653695         7.9                   25.82     790101
# 2         1489.406472         8.8                   29.12     803513
# 3         1285.450128        10.3                   29.75     816687
# 4         1250.000000        10.2                   68.86    3300935
#
#        Ln_SP    Ln_Educ    Ln_Sal  Ln_População  cnst  Lag_Ln_SP  SP por Pop  \
# 0  19.733493  20.569398  7.406103     13.562504     1        NaN  478.659225
# 1  19.837383  20.568010  7.366226     13.579916     1  19.733493  521.895231
# 2  19.686925  20.485503  7.306133     13.596749     1  19.837383  441.499247
# 3  19.661894  20.476492  7.158864     13.613011     1  19.686925  423.639292
# 4  20.670635  20.667909  7.130899     15.009716     1        NaN  287.412577
#
#    Educ por Pop
# 0   1104.219644
# 1   1083.654083
# 2    981.178814
# 3    956.691720
# 4    286.630181

# %%
cols=list(dados.columns)
for i in range(len(cols)):
    print(str(i)+' '+cols[i])
# Out:
# 0 Estado
# 1 Sigla
# 2 Ano
# 3 Seguranca Publica Real
# 4 Educacao Real
# 5 Salário médio real
# 6 Desemprego
# 7 Tx de mortes violentas
# 8 População
# 9 Ln_SP
# 10 Ln_Educ
# 11 Ln_Sal
# 12 Ln_População
# 13 cnst
# 14 Lag_Ln_SP
# 15 SP por Pop
# 16 Educ por Pop

# %% [markdown]
# ##### Third regression's independent variables

# %%
cols_reg3=[cols[6]]+[cols[11]]+[cols[13]]+cols[15:]
cols_reg3
# Out:
# ['Desemprego', 'Ln_Sal', 'cnst', 'SP por Pop', 'Educ por Pop']

# %%
result=sm.OLS(dados['Tx de mortes violentas'],dados[cols_reg3]).fit()
print(result.summary())
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Tx de mortes violentas   R-squared:                       0.324
# Model:                                OLS   Adj. R-squared:                  0.298
# Method:                     Least Squares   F-statistic:                     12.33
# Date:                    Fri, 23 Feb 2018   Prob (F-statistic):           3.12e-08
# Time:                            14:24:46   Log-Likelihood:                -405.90
# No. Observations:                     108   AIC:                             821.8
# Df Residuals:                         103   BIC:                             835.2
# Df Model:                               4
# Covariance Type:                nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [95.0% Conf. Int.]
# --------------------------------------------------------------------------------
# Desemprego       1.6442      0.435      3.784      0.000         0.782     2.506
# Ln_Sal          -8.7813      4.483     -1.959      0.053       -17.673     0.110
# cnst            87.5952     33.932      2.582      0.011        20.299   154.891
# SP por Pop       0.0060      0.010      0.605      0.546        -0.014     0.026
# Educ por Pop    -0.0103      0.004     -2.299      0.024        -0.019    -0.001
# ==============================================================================
# Omnibus:                        1.320   Durbin-Watson:                   0.927
# Prob(Omnibus):                  0.517   Jarque-Bera (JB):                1.392
# Skew:                           0.246   Prob(JB):                        0.499
# Kurtosis:                       2.740   Cond. No.                     2.04e+04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.04e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ##### zilch

# %%
plt.figure()
plt.scatter(dados['SP por Pop'],dados['Tx de mortes violentas'])
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.1666666666666">

# %% [markdown]
# ##### Let's try using log versions even though log(A/B)=log(A)-log(B), just because it runs better.

# %%
dados['Ln_SP_Pop']=np.log(dados['SP por Pop'])
dados['Ln_Educ_Pop']=np.log(dados['Educ por Pop'])
dados.head()
# Out:
#     Estado Sigla   Ano  Seguranca Publica Real  Educacao Real  \
# 0     Acre    AC  2013             371661177.6    857385697.7
# 1     Acre    AC  2014             412349943.8    856196174.8
# 2     Acre    AC  2015             354750384.1    788389932.2
# 3     Acre    AC  2016             345980702.1    781317690.5
# 4  Alagoas    AL  2013             948730236.2    946147596.4
#
#    Salário médio real  Desemprego  Tx de mortes violentas  População  \
# 0         1646.000000         8.4                   27.69     776463
# 1         1581.653695         7.9                   25.82     790101
# 2         1489.406472         8.8                   29.12     803513
# 3         1285.450128        10.3                   29.75     816687
# 4         1250.000000        10.2                   68.86    3300935
#
#        Ln_SP    Ln_Educ    Ln_Sal  Ln_População  cnst  Lag_Ln_SP  SP por Pop  \
# 0  19.733493  20.569398  7.406103     13.562504     1        NaN  478.659225
# 1  19.837383  20.568010  7.366226     13.579916     1  19.733493  521.895231
# 2  19.686925  20.485503  7.306133     13.596749     1  19.837383  441.499247
# 3  19.661894  20.476492  7.158864     13.613011     1  19.686925  423.639292
# 4  20.670635  20.667909  7.130899     15.009716     1        NaN  287.412577
#
#    Educ por Pop  Ln_SP_Pop  Ln_Educ_Pop
# 0   1104.219644   6.170989     7.006894
# 1   1083.654083   6.257467     6.988094
# 2    981.178814   6.090176     6.888755
# 3    956.691720   6.048882     6.863481
# 4    286.630181   5.660919     5.658193

# %%
cols=list(dados.columns)
for i in range(len(cols)):
    print(str(i)+' '+cols[i])
# Out:
# 0 Estado
# 1 Sigla
# 2 Ano
# 3 Seguranca Publica Real
# 4 Educacao Real
# 5 Salário médio real
# 6 Desemprego
# 7 Tx de mortes violentas
# 8 População
# 9 Ln_SP
# 10 Ln_Educ
# 11 Ln_Sal
# 12 Ln_População
# 13 cnst
# 14 Lag_Ln_SP
# 15 SP por Pop
# 16 Educ por Pop
# 17 Ln_SP_Pop
# 18 Ln_Educ_Pop

# %% [markdown]
# ##### Fourth regression's independent variables

# %%
cols_reg4=[cols[6]]+[cols[11]]+[cols[13]]+cols[17:19]
cols_reg4
# Out:
# ['Desemprego', 'Ln_Sal', 'cnst', 'Ln_SP_Pop', 'Ln_Educ_Pop']

# %%
result=sm.OLS(dados['Tx de mortes violentas'],dados[cols_reg4]).fit()
print(result.summary())
# Out:
#                               OLS Regression Results
# ==================================================================================
# Dep. Variable:     Tx de mortes violentas   R-squared:                       0.355
# Model:                                OLS   Adj. R-squared:                  0.330
# Method:                     Least Squares   F-statistic:                     14.19
# Date:                    Fri, 23 Feb 2018   Prob (F-statistic):           2.94e-09
# Time:                            14:24:46   Log-Likelihood:                -403.34
# No. Observations:                     108   AIC:                             816.7
# Df Residuals:                         103   BIC:                             830.1
# Df Model:                               4
# Covariance Type:                nonrobust
# ===============================================================================
#                   coef    std err          t      P>|t|      [95.0% Conf. Int.]
# -------------------------------------------------------------------------------
# Desemprego      1.5383      0.406      3.789      0.000         0.733     2.343
# Ln_Sal         -9.4401      4.324     -2.183      0.031       -18.015    -0.865
# cnst          111.0373     28.384      3.912      0.000        54.744   167.331
# Ln_SP_Pop       3.8073      1.838      2.072      0.041         0.162     7.452
# Ln_Educ_Pop    -6.9272      2.551     -2.715      0.008       -11.987    -1.867
# ==============================================================================
# Omnibus:                        1.362   Durbin-Watson:                   0.978
# Prob(Omnibus):                  0.506   Jarque-Bera (JB):                1.440
# Skew:                           0.241   Prob(JB):                        0.487
# Kurtosis:                       2.703   Cond. No.                         401.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ##### Spoiler alert: It won't get better so I'll just use these results to find how much education expenditure would be needed to reduce crime rates. At least now we have one less warning message.

# %% [markdown]
# #
#
#
#
# ### Notice that:
# $$ \hat{Y}= \sum{\hat{\beta}*X}+\hat{U}$$
# ### by rearranging we get:
# $$ \frac{\hat{Y} - \sum_{X\neq Educ}{\hat{\beta}*X}-\hat{U}}{\hat{\beta}_{Educ}} = Educ $$
# ### So if we substitute $\hat{Y}$ by the target value we want, São Paulo's violent death rate, we find how much each State should have spent in education.

# %%
dados['Ln_Gasto_Nec_Educ']=(float(dados.loc[(dados['Sigla']=='SP') & 
                                  (dados['Ano']==2016),'Tx de mortes violentas'])
                            -result.resid
                            -result.params[0]*dados['Desemprego']
                        -result.params[1]*dados['Ln_Sal']
                         -result.params[2]*dados['cnst']
                         -result.params[3]*dados['Ln_SP_Pop']                
                        )/result.params[4]

# %% [markdown]
# ### Let's do a sanity check to confirm we got what we wanted. The value São Paulo *should* have spent is supposed to be the same value São Paulo *did* spend since it's the state we choose as a reference.

# %%
dados.loc[(dados['Sigla']=='SP') &(dados['Ano']==2016),['Ln_Educ_Pop','Ln_Gasto_Nec_Educ']]
# Out:
#     Ln_Educ_Pop  Ln_Gasto_Nec_Educ
# 99     6.258388           6.258388

# %% [markdown]
# ##### The values match. All is right in the world!

# %% [markdown]
# ### Noew, let's take a peek at the results of how much each state should have spent and how much it did spend.

# %%
dados[['Ln_Gasto_Nec_Educ','Ln_Educ_Pop']]
# Out:
#      Ln_Gasto_Nec_Educ  Ln_Educ_Pop
# 0             9.414776     7.006894
# 1             9.126028     6.988094
# 2             9.503068     6.888755
# 3             9.568740     6.863481
# 4            14.009270     5.658193
# 5            13.686902     5.709710
# 6            11.757395     5.534146
# 7            11.579104     5.100343
# 8            10.004530     6.782472
# 9            10.623288     6.945061
# 10            9.855001     6.736880
# 11           12.110956     6.540202
# 12            8.245492     6.100341
# 13            9.071668     6.185963
# 14            9.838875     6.124558
# 15            8.680036     6.023859
# 16            9.712746     5.519163
# 17           10.050205     5.563576
# 18            9.894515     5.527703
# 19           10.632735     5.503716
# 20           11.263844     5.566056
# 21           11.333858     5.591319
# 22           10.581797     5.475874
# 23            9.662921     5.509758
# 24            9.442497     7.187634
# 25            9.493395     7.200999
# 26            9.344348     7.496573
# 27            8.787546     7.182291
# 28           10.364182     5.783720
# 29           10.301882     5.849899
# ..                 ...          ...
# 78           11.047908     5.679255
# 79           12.379883     5.761094
# 80            6.760672     5.708307
# 81            7.630995     5.754348
# 82            7.724853     5.722615
# 83            7.858453     5.561726
# 84            8.810018     6.264996
# 85            9.091565     6.223183
# 86            8.989818     6.154638
# 87            9.306329     6.162224
# 88            8.524306     6.949366
# 89            7.523838     6.846802
# 90            8.102715     6.780401
# 91            8.048786     6.774110
# 92            6.129497     5.917292
# 93            6.347587     5.960709
# 94            6.384900     5.908521
# 95            6.404002     5.825129
# 96            6.510852     6.291429
# 97            6.662845     6.345259
# 98            6.427901     6.328294
# 99            6.258388     6.258388
# 100          10.576382     5.906419
# 101          11.292757     5.877910
# 102          12.480061     5.791981
# 103          13.354092     5.711809
# 104           7.927986     6.402128
# 105           8.107691     6.293118
# 106           8.377037     6.203014
# 107           8.539139     6.220758
#
# [108 rows x 2 columns]

# %% [markdown]
# ### We're very close to what we wanted, all that is left is to find the difference between what should have been to what was. For simplicity we restrain ourselves to 2016.
#
# ##### Notice that we're using this data on logarithm scale and $Ln(A)-Ln(B)\approx \Delta_{A-B}\%$ so the difference we're calculating is approximatly the percentage variation we needed in expenditure to get to our target.

# %%
dados['dif_nec_gasto']=dados.loc[dados['Ano']==2016,'Ln_Gasto_Nec_Educ']-dados.loc[dados['Ano']==2016,'Ln_Educ_Pop']

# %% [markdown]
# ### We got results for each state but what about the country in general? Let's take the unweighted mean (for simplicity) to find out.

# %%
(dados.loc[dados['Ano']==2016,'Ln_Gasto_Nec_Educ']-dados.loc[dados['Ano']==2016,'Ln_Educ_Pop']).mean()
# Out:
# 3.396837393656256

# %% [markdown]
# ### There we have it. States should have spent 339% more "on average" to get the same violent death rate as São Paulo. To get the actual result we would need to weight each value by the original spending values.

# %%
#Saving the result
dados.to_csv('E:\\Outros arquivos e pastas\\blogs\\gastos e violencia\\dados_2016.csv')

# %% [markdown]
# ### Let's see the result for each state:

# %%
cols=list(dados.columns)
for i in range(len(cols)):
    print(str(i)+' '+cols[i])
# Out:
# 0 Estado
# 1 Sigla
# 2 Ano
# 3 Seguranca Publica Real
# 4 Educacao Real
# 5 Salário médio real
# 6 Desemprego
# 7 Tx de mortes violentas
# 8 População
# 9 Ln_SP
# 10 Ln_Educ
# 11 Ln_Sal
# 12 Ln_População
# 13 cnst
# 14 Lag_Ln_SP
# 15 SP por Pop
# 16 Educ por Pop
# 17 Ln_SP_Pop
# 18 Ln_Educ_Pop
# 19 Ln_Gasto_Nec_Educ
# 20 dif_nec_gasto

# %%
result_cols=cols[:3]+[cols[20]]
result_cols
# Out:
# ['Estado', 'Sigla', 'Ano', 'dif_nec_gasto']

# %%
dados.loc[dados['Ano']==2016,result_cols]
# Out:
#                   Estado Sigla   Ano  dif_nec_gasto
# 3                   Acre    AC  2016   2.705258e+00
# 7                Alagoas    AL  2016   6.478762e+00
# 11                 Amapá    AP  2016   5.570753e+00
# 15              Amazonas    AM  2016   2.656177e+00
# 19                 Bahia    BA  2016   5.129020e+00
# 23                 Ceará    CE  2016   4.153163e+00
# 27      Distrito Federal    DF  2016   1.605255e+00
# 31        Espírito Santo    ES  2016   3.118121e+00
# 35                 Goiás    GO  2016   4.736367e+00
# 39              Maranhão    MA  2016   3.272583e+00
# 43           Mato Grosso    MT  2016   3.529539e+00
# 47    Mato Grosso do Sul    MS  2016   1.683208e+00
# 51          Minas Gerais    MG  2016   1.413259e+00
# 55                  Pará    PA  2016   5.755531e+00
# 59               Paraíba    PB  2016   3.181638e+00
# 63                Paraná    PR  2016   2.152369e+00
# 67            Pernambuco    PE  2016   5.280595e+00
# 71                 Piauí    PI  2016   1.574940e+00
# 75        Rio de Janeiro    RJ  2016   3.844239e+00
# 79   Rio Grande do Norte    RN  2016   6.618788e+00
# 83     Rio Grande do Sul    RS  2016   2.296727e+00
# 87              Rondônia    RO  2016   3.144105e+00
# 91               Roraima    RR  2016   1.274676e+00
# 95        Santa Catarina    SC  2016   5.788733e-01
# 99             São Paulo    SP  2016   1.776357e-15
# 103              Sergipe    SE  2016   7.642283e+00
# 107            Tocantins    TO  2016   2.318380e+00

# %% [markdown]
# ### Now let's visualize our results.

# %%
plt.figure()
plt.title("Violent Death and Necessary Education expenditure change by state")
UFs=list(dados['Sigla'].unique())
plt.scatter(dados.loc[dados["Ano"]==2016,'Tx de mortes violentas'],dados.loc[dados["Ano"]==2016,'dif_nec_gasto'])
ds=dados[dados["Ano"]==2016].sort_values(by='dif_nec_gasto').reset_index()
plt.xlabel('Violent Death Rate')
plt.ylabel('Necessary change in Education expenditure')
for i in range(27):
    x=ds.loc[i,'Tx de mortes violentas']
    y=ds.loc[i,'dif_nec_gasto']
    if i%2 ==0:
        plt.annotate(ds.loc[i,'Sigla'],(x,y),(x+1,y-0.3))
    else:
        plt.annotate(ds.loc[i,'Sigla'],(x,y),(x-1,y+0.3))
# Out:
# <img src="data:image/png;base64,..." width="639.1666666666666">

# %%
plt.figure()
plt.title("Current education exp and Necessary education exp change by state")
UFs=list(dados['Sigla'].unique())
plt.scatter(dados.loc[dados["Ano"]==2016,'Ln_Educ_Pop'],dados.loc[dados["Ano"]==2016,'dif_nec_gasto'])
ds=dados[dados["Ano"]==2016].sort_values(by='dif_nec_gasto').reset_index()
plt.xlabel('Current Education Expenditure')
plt.ylabel('Necessary change in Education expenditure')
for i in range(27):
    x=ds.loc[i,'Ln_Educ_Pop']
    y=ds.loc[i,'dif_nec_gasto']
    plt.annotate(ds.loc[i,'Sigla'],(x,y),(x+.05,y-0.3))
# Out:
# <img src="data:image/png;base64,..." width="639.1666666666666">
